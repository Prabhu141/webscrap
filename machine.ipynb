# %% [markdown]
# <a href="https://colab.research.google.com/github/Prabhu141/webscrap/blob/main/machine.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import requests
import pandas as pd
import csv
import re

import random
user_agent_list = [
'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/37.0.2062.94 Chrome/37.0.2062.94 Safari/537.36', 
'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/45.0.2454.85 Safari/537.36', 
'Mozilla/5.0 (Windows NT 6.1; WOW64; Trident/7.0; rv:11.0) like Gecko', 
'Mozilla/5.0 (Windows NT 6.1; WOW64; rv:40.0) Gecko/20100101 Firefox/40.0', 
'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_5) AppleWebKit/600.8.9 (KHTML, like Gecko) Version/8.0.8 Safari/600.8.9', 
'Mozilla/5.0 (iPad; CPU OS 8_4_1 like Mac OS X) AppleWebKit/600.1.4 (KHTML, like Gecko) Version/8.0 Mobile/12H321 Safari/600.1.4', 
'Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/45.0.2454.85 Safari/537.36', 
'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/45.0.2454.85 Safari/537.36', 
'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/42.0.2311.135 Safari/537.36 Edge/12.10240', 
'Mozilla/5.0 (Windows NT 6.3; WOW64; rv:40.0) Gecko/20100101 Firefox/40.0', 
'Mozilla/5.0 (Windows NT 6.3; WOW64; Trident/7.0; rv:11.0) like Gecko', 
'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/45.0.2454.85 Safari/537.36', 
'Mozilla/5.0 (Windows NT 6.1; Trident/7.0; rv:11.0) like Gecko', 
'Mozilla/5.0 (Windows NT 10.0; WOW64; rv:40.0) Gecko/20100101 Firefox/40.0', 
'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_4) AppleWebKit/600.7.12 (KHTML, like Gecko) Version/8.0.7 Safari/600.7.12', 
'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/45.0.2454.85 Safari/537.36', 
'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.10; rv:40.0) Gecko/20100101 Firefox/40.0', 
'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_5) AppleWebKit/600.8.9 (KHTML, like Gecko) Version/7.1.8 Safari/537.85.17', 
'Mozilla/5.0 (iPad; CPU OS 8_4 like Mac OS X) AppleWebKit/600.1.4 (KHTML, like Gecko) Version/8.0 Mobile/12H143 Safari/600.1.4', 
'Mozilla/5.0 (iPad; CPU OS 8_3 like Mac OS X) AppleWebKit/600.1.4 (KHTML, like Gecko) Version/8.0 Mobile/12F69 Safari/600.1.4', 
'Mozilla/5.0 (Windows NT 6.1; rv:40.0) Gecko/20100101 Firefox/40.0', 
'Mozilla/5.0 (compatible; MSIE 10.0; Windows NT 6.1; WOW64; Trident/6.0)', 
'Mozilla/5.0 (compatible; MSIE 9.0; Windows NT 6.1; WOW64; Trident/5.0)',]

for i in range(1,2):
  #Pick a random user agent
  user_agent = random.choice(user_agent_list)
  headers = {'User-Agent': user_agent }

url_links = [
             'https://www.machinelist.us/company-treys-fuel-injectin-in-hewitt-tx-39275',
             'https://www.machinelist.us/company-dfw-machines-inc-in-houston-tx-39281',
             'https://www.machinelist.us/company-metal-removal-specialties-in-odessa-tx-39292',
             'https://www.machinelist.us/company-parker-hannifin-corp-in-richardson-tx-39301',
             'https://www.machinelist.us/company-dalworth-machine-products-in-fort-worth-tx-39308',
             'https://www.machinelist.us/company-waller-machining-in-waller-tx-39319',
             'https://www.machinelist.us/company-global-stencil-inc-in-grand-prairie-tx-39324',
             'https://www.machinelist.us/company-campat-machine-tool-in-houston-tx-39335',
             'https://www.machinelist.us/company-p-w-quality-machine-inc-in-cedar-hill-tx-39340',
             'https://www.machinelist.us/company-ultra-tool-plastics-in-mc-dade-tx-39346',
             'https://www.machinelist.us/company-radford-manufacturing-inc-in-fort-worth-tx-39351',
             'https://www.machinelist.us/company-custom-cutting-technologies-in-grapevine-tx-39360',
             'https://www.machinelist.us/company-american-diesel-injection-in-la-porte-tx-39369',
             'https://www.machinelist.us/company-american-diesel-injection-in-houston-tx-39371',
             'https://www.machinelist.us/company-rotex-in-dallas-tx-39372',
             'https://www.machinelist.us/company-gillespies-engine-svc-in-groves-tx-39373',
             'https://www.machinelist.us/company-mid-south-machinery-inc-in-white-oak-tx-39418',
             'https://www.machinelist.us/company-bjl-machine-rig-repair-in-odessa-tx-39435',
             'https://www.machinelist.us/company-p-m-industries-in-lancaster-tx-39440',
             'https://www.machinelist.us/company-percision-enterprise-in-woodville-tx-39448',
             'https://www.machinelist.us/company-precision-enterprise-in-woodville-tx-39450',
             'https://www.machinelist.us/company-absolute-machine-tool-in-leander-tx-39451',
             'https://www.machinelist.us/company-powell-tool-grinding-inc-in-magnolia-tx-39456',
             'https://www.machinelist.us/company-1-machine-inc-in-waco-tx-39481',
             'https://www.machinelist.us/company-lawley-machine-shop-auto-in-texarkana-tx-39497',
             'https://www.machinelist.us/company-headway-research-inc-in-garland-tx-39517',
             'https://www.machinelist.us/company-g-t-sales-in-fort-worth-tx-39526',
             'https://www.machinelist.us/company-micro-precision-inc-in-houston-tx-39528',
             'https://www.machinelist.us/company-advantage-machine-mfg-in-plano-tx-39542',
             'https://www.machinelist.us/company-texas-flange-inc-in-odessa-tx-39549',
             'https://www.machinelist.us/company-wier-manufacturing-co-in-san-antonio-tx-39567',
             'https://www.machinelist.us/company-tjw-enterprises-in-san-antonio-tx-39585',
             'https://www.machinelist.us/company-global-heat-exchanger-inc-in-vidor-tx-39588',
             'https://www.machinelist.us/company-snapp-tool-die-inc-in-el-paso-tx-39598',
             'https://www.machinelist.us/company-elliott-ace-engine-svc-in-olney-tx-39620',
             'https://www.machinelist.us/company-agh-machine-in-houston-tx-39638',
             'https://www.machinelist.us/company-gardener-denver-petro-pumps-in-odessa-tx-39641',
             'https://www.machinelist.us/company-baham-sone-machine-works-in-houston-tx-39677',
             'https://www.machinelist.us/company-gulfcoast-deisel-svc-in-houston-tx-39678',
             'https://www.machinelist.us/company-j-m-machine-works-in-houston-tx-39685',
             'https://www.machinelist.us/company-draworks-in-boling-tx-39686',
             'https://www.machinelist.us/company-macro-tech-in-el-paso-tx-39689',
             'https://www.machinelist.us/company-alamo-city-riggers-in-atascosa-tx-39703',
             'https://www.machinelist.us/company-akjetam-co-in-houston-tx-39743',
             'https://www.machinelist.us/company-custom-parts-specialists-in-angleton-tx-39746',
             'https://www.machinelist.us/company-huffco-metals-machining-in-houston-tx-39762',
             'https://www.machinelist.us/company-kemp-equipment-co-in-haltom-city-tx-39770',
             'https://www.machinelist.us/company-p-v-machine-shop-in-dickinson-tx-39801',
             'https://www.machinelist.us/company-v-h-machine-works-in-houston-tx-39813',
             'https://www.machinelist.us/company-garden-equipment-sales-inc-in-corpus-christi-tx-39822',
             'https://www.machinelist.us/company-houston-excelsweld-svc-in-houston-tx-39823',
             'https://www.machinelist.us/company-h-r-wilkins-co-inc-in-houston-tx-39830',
             'https://www.machinelist.us/company-humble-machine-works-inc-in-humble-tx-39848',
             'https://www.machinelist.us/company-goza-products-in-garland-tx-39903',
             'https://www.machinelist.us/company-german-elektronik-in-san-antonio-tx-39928',
             'https://www.machinelist.us/company-harris-co-in-houston-tx-39929',
             'https://www.machinelist.us/company-c-b-machine-in-mesquite-tx-39939',
             'https://www.machinelist.us/company-cameron-machine-shop-in-richardson-tx-39957',
             'https://www.machinelist.us/company-precise-engine-svc-in-new-braunfels-tx-39987',
             'https://www.machinelist.us/company-harolds-automotive-machine-in-richmond-tx-39998',
             'https://www.machinelist.us/company-h-p-racing-engines-in-tomball-tx-40046',
             'https://www.machinelist.us/company-mollart-north-america-inc-in-spring-tx-40076',
             'https://www.machinelist.us/company-birchfield-machining-in-austin-tx-40083',
          
  
             
             ]

# get all data from URLs
all_data = []
for url in url_links:
    #print(url)

    req = requests.get(url, headers = headers)
    soup = BeautifulSoup(req.text, "html.parser")

    Company_name = soup.find('div', class_="field field-name-field-company-name field-type-text field-label-inline clearfix")
    About = soup.find('div', class_="field field-name-body field-type-text-with-summary field-label-hidden")
    Location_street = soup.find('div', class_="field field-name-field-location-street field-type-text field-label-inline clearfix")
    Location_city = soup.find('div', class_="field field-name-field-location-city field-type-text field-label-inline clearfix")
    Location_zip = soup.find('div', class_="field field-name-field-location-zip field-type-text field-label-inline clearfix")
    Location_county = soup.find('div', class_="field field-name-field-county field-type-text field-label-inline clearfix")
    Location_state = soup.find('div', class_="field field-name-field-state field-type-text field-label-inline clearfix")
    #Contact_name = soup.find('div', class_="field field-name-field-contact-name field-type-text field-label-inline clearfix")
    #Contact_role = soup.find('div', class_="field field-name-field-contact-role field-type-text field-label-inline clearfix")
    About_address = soup.find('div', class_="field field-name-field-text3 field-type-text-long field-label-hidden")
    Address = soup.find('p', class_="simple-gmap-address")
    About_contact = soup.find('div', class_="field field-name-field-beschreibung field-type-text-long field-label-hidden")
    About_mail = soup.find('div', class_="field field-name-field-text8 field-type-text field-label-hidden")
    Mailing_street = soup.find('div', class_="field field-name-field-mailing-street field-type-text field-label-inline clearfix")
    Mailing_city = soup.find('div', class_="field field-name-field-mailing-city field-type-text field-label-inline clearfix")
    Mailing_zip = soup.find('div', class_="field field-name-field-mailing-zip field-type-text field-label-inline clearfix")
    Mailing_state = soup.find('div', class_="field field-name-field-mailing-state field-type-text field-label-inline clearfix")
    Details = soup.find('div', class_="field field-name-field-text2 field-type-text-long field-label-hidden")
    Contact_number = soup.find('div', class_="field field-name-field-phone-number field-type-text field-label-inline clearfix")
    Contact_details = soup.find('div', class_="field field-name-field-text6 field-type-text field-label-hidden")
    About_details = soup.find('div', class_="field field-name-field-text7 field-type-text field-label-hidden")

    all_data.append(
    [
        Company_name.get_text(strip=True),
        About.get_text(strip=True),
        Location_street.get_text(strip=True),
        Location_city.get_text(strip=True),
        Location_zip.get_text(strip=True),
        Location_county.get_text(strip=True),
        Location_state.get_text(strip=True),
        #Contact_name.get_text(strip=True),
        #Contact_role.get_text(strip=True),
        About_address.get_text(strip=True),
        Address.get_text(strip=True),
        About_contact.get_text(strip=True),
        About_mail.get_text(strip=True),
        Mailing_street.get_text(strip=True),
        Mailing_city.get_text(strip=True),
        Mailing_zip.get_text(strip=True),
        Mailing_state.get_text(strip=True),
        Details.get_text(strip=True),
        Contact_number.get_text(strip=True),
        Contact_details.get_text(strip=True),
        About_details.get_text(strip=True),
        ]
        )

# save data to CSV
df = pd.DataFrame(
    all_data,
    columns=[
        "Company_name",
        "About", 
        "Location_street", 
        "Location_city",
        "Location_zip",
        "Location_county",
        "Location_state",
        #"Contact_name",
        #"Contact_role",
        "About_address",
        "Address",
        "About_contact",
        "About_mail",
        "Mailing_street",
        "Mailing_city",
        "Mailing_zip",
        "Mailing_state",
        "Details",
        "Contact_number",
        "Contact_details",
        "About_details",
    ]
)
print(df)
df.to_csv("page281-287.csv", index=None)
# Out:
#                                 Company_name  \
# 0          COMPANY NAME:Trey's Fuel Injectin
# 1              COMPANY NAME:DFW Machines Inc
# 2     COMPANY NAME:Metal Removal Specialties
# 3          COMPANY NAME:Parker-Hannifin Corp
# 4     COMPANY NAME:Dalworth Machine Products
# ..                                       ...
# 58           COMPANY NAME:Precise Engine Svc
# 59  COMPANY NAME:Harold's Automotive Machine
# 60           COMPANY NAME:H P Racing Engines
# 61    COMPANY NAME:Mollart North America Inc
# 62         COMPANY NAME:Birchfield Machining
#
#                                                 About  \
# 0   On this page you will find important informati...
# 1   On this page you will find important informati...
# 2   On this page you will find important informati...
# 3   On this page you will find important informati...
# 4   On this page you will find important informati...
# ..                                                ...
# ...

# %% [markdown]
# # New section
